# %%
import pandas as pd # type: ignore

# %%
# Liste der gesamten Indikatoren wird geladen

data = pd.read_csv("out/data.csv")
data.head()
# Out:
#   select  category    category_de  category_nl  name  \
# 0    NaN       NaN  Absolutzahlen          NaN   NaN
# 1    NaN       NaN  Absolutzahlen          NaN   NaN
# 2    NaN       NaN  Absolutzahlen          NaN   NaN
# 3    NaN       NaN  Absolutzahlen          NaN   NaN
# 4    NaN       NaN  Absolutzahlen          NaN   NaN
#
#                                              name_de algorithmus  \
# 0                                        Arbeitslose         NaN
# 1                  Bruttoinlandsprodukt in 1000 Euro         NaN
# 2  Sozialversicherungspflichtig Beschäftigte am W...         NaN
# 3  Sozialversicherungspflichtig Beschäftigte am A...         NaN
# 4    Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)         NaN
#
#                                          description  \
# 0  Es handelt sich um die Zahl der Arbeitslosen i...
# 1  Das Bruttoinlandsprodukt (BIP) misst die Produ...
# 2  Es handelt sich um die Zahl der sozialversiche...
# 3  Es handelt sich um die Zahl der sozialversiche...
# 4  Zwischen der Zahl der Bevölkerung am 31.12.201...
#
#                                    statistical_basis  name_nl source_de  \
# 0  Arbeitsmarktstatistik der Bundesagentur für Ar...      NaN     Inkar
# 1  Arbeitskreis "Volkswirtschaftliche Gesamtrechn...      NaN     Inkar
# 2  Beschäftigtenstatistik der Bundesagentur für A...      NaN     Inkar
# 3  Beschäftigtenstatistik der Bundesagentur für A...      NaN     Inkar
# 4  Bundesinstitut für Bau-, Stadt- und Raumforsch...      NaN     Inkar
#
#    source_id_de  source_nl  source_id_nl gemeinden kreise zeitbezug_gemeinden  \
# 0          2176        NaN           NaN       NaN      X                 NaN
# 1          4273        NaN           NaN       NaN      X                 NaN
# 2          8766        NaN           NaN       NaN      X                 NaN
# 3          8774        NaN           NaN       NaN      X                 NaN
# 4         10806        NaN           NaN       NaN      X                 NaN
#
#   zeitbezug_kreise
# 0      1995 - 2020
# 1      2000 - 2020
# 2      1997 - 2020
# 3      1997 - 2020
# 4      1995 - 2020

# %%
# Code um die ausgewählten Indicatoren zu filtern und in einer csv abzuspeichern

indicators = pd.DataFrame(columns=['category_de', 'name_de', 'source_de', 'source_id_de', 'category_nl', 'name_nl', 'source_nl', 'source_id_nl'])

for index in data.index:
    if data['select'][index] == "x":
        print(index)
        category_value = data['category_de'][index]
        indicator_name = data['name_de'][index]
        source_value = data['source_de'][index]
        source_id_value = int(data['source_id_de'][index])
        indicators.loc[len(indicators)] = {'category_de': category_value, 'name_de': indicator_name, 'source_de': source_value, 'source_id_de':source_id_value}


indicators.reset_index(drop=True, inplace=True)
#indicators.to_csv("C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/indicators.csv", index=False)
#indicators.to_excel("C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/indicators.xlsx", index=False)
indicators
# Out:
# 5
# 8
# 10
# 186
# 187
# 196
# 203
# 338
#          category_de                                            name_de  \
# 0      Absolutzahlen                                 Bevölkerung gesamt
# 1      Absolutzahlen  Erwerbsfähige Bevölkerung (15 bis unter 65 Jahre)
# 2      Absolutzahlen                                      Erwerbstätige
# 3        Bevölkerung                 Geburten junger Mütter (<20 Jahre)
# 4        Bevölkerung               Geburten älterer Mütter (>=40 Jahre)
# 5        Bevölkerung                              Haushalte mit Kindern
# 6            Bildung                                        Studierende
# 7  Siedlungsstruktur                                    Einwohnerdichte
#
#   source_de  source_id_de  category_nl  name_nl  source_nl  source_id_nl
# 0     Inkar         12586          NaN      NaN        NaN           NaN
# 1     Inkar         16607          NaN      NaN        NaN           NaN
# 2     Inkar         18602          NaN      NaN        NaN           NaN
# 3     Inkar         17347          NaN      NaN        NaN           NaN
# 4     Inkar         17348          NaN      NaN        NaN           NaN
# 5     Inkar         17800          NaN      NaN        NaN           NaN
# 6     Inkar         15146          NaN      NaN        NaN           NaN
# 7     Inkar         17186          NaN      NaN        NaN           NaN

# %%
#Liest den Inkar Datensatz ein

inkar = pd.read_csv("../data/inkar_2022.csv",sep=";",decimal=",",dtype={'Kennziffer':str,'Kennziffer_EU':str,'Name':str}, low_memory=False)
inkar.head()
# Out:
#          Bereich    ID    Indikator             Raumbezug Kennziffer  \
# 0  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 1  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 2  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 3  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 4  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
#
#         Name  Zeitbezug     Wert
# 0  Flensburg       1995  10494.0
# 1  Flensburg       1996  11921.0
# 2  Flensburg       1997  13213.0
# 3  Flensburg       1998  13301.0
# 4  Flensburg       1999  12048.0

# %%
# Legt die Selektion des Raums fest und filtert den Datensatz danach

raumbezug_selection = ["Kreise","Gemeinden", "Bund", "Bundesländer", "Gemeindeverbände"]
#raumbezug_selection = ["Bund"]
inkar = inkar[inkar['Raumbezug'].isin(raumbezug_selection)]

# %%
#Filternt den gesamten Inkardatensatz aufgrund der Kategorien, QuellenID und Name von den Indikatoren

filtered_inkar = inkar[(inkar['Bereich'].isin(indicators['category_de'])) & (inkar['ID'].isin(indicators['source_id_de'])) & (inkar['Indikator'].isin(indicators['name_de']))]
filtered_inkar.reset_index(drop=True, inplace=True)
filtered_inkar.head()
#filtered_inkar.to_csv("C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/filtered_inkar2.csv", index=False)
# Out:
#          Bereich     ID           Indikator Raumbezug Kennziffer  \
# 0  Absolutzahlen  12586  Bevölkerung gesamt      Bund        111
# 1  Absolutzahlen  12586  Bevölkerung gesamt      Bund        111
# 2  Absolutzahlen  12586  Bevölkerung gesamt      Bund        111
# 3  Absolutzahlen  12586  Bevölkerung gesamt      Bund        111
# 4  Absolutzahlen  12586  Bevölkerung gesamt      Bund        111
#
#                          Name  Zeitbezug        Wert
# 0  Bundesrepublik Deutschland       1995  81817498.0
# 1  Bundesrepublik Deutschland       1996  82012160.0
# 2  Bundesrepublik Deutschland       1997  82057380.0
# 3  Bundesrepublik Deutschland       1998  82037011.0
# 4  Bundesrepublik Deutschland       1999  82163476.0

# %%
#Erstellt für jedem Indikator in der Indikator csv eine eigene csv mit den Werten

#print(filtered_inkar['Bereich'].unique())
indicators_csv = filtered_inkar['Indikator'].unique()
wanted_columns = ["Kennziffer", "Wert", "Zeitbezug"]
for indikator in indicators_csv:
    
    currentData = filtered_inkar[filtered_inkar['Indikator'] == indikator]
    currentData = currentData[wanted_columns]
    #indikator = indikator.split(" ")[0];
    indikator = indikator.replace(" ", "")
    indikator = indikator.replace("<", "")
    indikator = indikator.replace(">", "")
    print(indikator)
    fileName = f"C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/indicator_{indikator}.csv"
    currentData.to_csv(fileName, index=False)
# Out:
# Bevölkerunggesamt
# ErwerbsfähigeBevölkerung(15bisunter65Jahre)
# Erwerbstätige
# GeburtenjungerMütter(20Jahre)
# GeburtenältererMütter(=40Jahre)
# HaushaltemitKindern
# Studierende
# Einwohnerdichte
