# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("model_translator/translated_data.csv", index_col="Unnamed: 0")
data.head()
# Out:
#   select          category    category_de  category_nl  \
# 0    NaN  Absolute numbers  Absolutzahlen          NaN
# 1      x  Absolute numbers  Absolutzahlen          NaN
# 2    NaN  Absolute numbers  Absolutzahlen          NaN
# 3    NaN  Absolute numbers  Absolutzahlen          NaN
# 4    NaN  Absolute numbers  Absolutzahlen          NaN
#
#                                                name  \
# 0                                        Unemployed
# 1  Population (with correction VZ 1987/Zensus 2011)
# 2                                  Total population
# 3                                   Population Male
# 4                                 Population female
#
#                                            name_de  name_nl source_de  \
# 0                                      Arbeitslose      NaN     Inkar
# 1  Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)      NaN     Inkar
# 2                               Bevölkerung gesamt      NaN     Inkar
# 3                             Bevölkerung männlich      NaN     Inkar
# 4                             Bevölkerung weiblich      NaN     Inkar
#
#    source_id_de  source_nl  source_id_nl  Zeitbezug_min  Zeitbezug_max  \
# 0          2176        NaN           NaN           1995           2020
# 1         10806        NaN           NaN           1995           2020
# 2         12586        NaN           NaN           1995           2020
# 3         12747        NaN           NaN           1995           2020
# 4         12746        NaN           NaN           1995           2020
#
#   Gemeinden Gemeindeverbände Kreise
# 0       NaN                X      X
# 1       NaN                X      X
# 2       NaN                X      X
# 3       NaN                X      X
# 4       NaN                X      X

# %%
indicators = pd.DataFrame(columns=['category', 'name', 'source', 'source_id'])

for index in data.index:
    if data['select'][index] == "x":
        print(index)
        category_value = data['category_de'][index]
        indicator_name = data['name_de'][index]
        source_value = data['source_de'][index]
        source_id_value = int(data['source_id_de'][index])
        indicators.loc[len(indicators)] = {'category': category_value, 'name': indicator_name, 'source': source_value, 'source_id':source_id_value}


indicators.reset_index(drop=True, inplace=True)
indicators.to_csv("C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/indicators_new.csv", index=False)
# Out:
# 1
# 67
# 155
# 426
# 444
# 542

# %%
inkar = pd.read_csv("../data/inkar_2022.csv",sep=";",decimal=",",dtype={'Kennziffer':str,'Kennziffer_EU':str,'Name':str}, low_memory=False)
inkar.head()
# Out:
#          Bereich    ID    Indikator             Raumbezug Kennziffer  \
# 0  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 1  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 2  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 3  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
# 4  Absolutzahlen  2176  Arbeitslose  Arbeitsmarktregionen        001
#
#         Name  Zeitbezug     Wert
# 0  Flensburg       1995  10494.0
# 1  Flensburg       1996  11921.0
# 2  Flensburg       1997  13213.0
# 3  Flensburg       1998  13301.0
# 4  Flensburg       1999  12048.0

# %%
raumbezug_selection = ["Kreise","Gemeinden", "Bund", "Bundesländer", "Gemeindeverbände"]
inkar = inkar[inkar['Raumbezug'].isin(raumbezug_selection)]

# %%
filtered_inkar = inkar[(inkar['Bereich'].isin(indicators['category'])) & (inkar['ID'].isin(indicators['source_id'])) & (inkar['Indikator'].isin(indicators['name']))]
filtered_inkar.reset_index(drop=True, inplace=True)
filtered_inkar.head()
#filtered_inkar.to_csv("C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/filtered_inkar2.csv", index=False)
# Out:
#          Bereich     ID                                        Indikator  \
# 0  Absolutzahlen  10806  Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)
# 1  Absolutzahlen  10806  Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)
# 2  Absolutzahlen  10806  Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)
# 3  Absolutzahlen  10806  Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)
# 4  Absolutzahlen  10806  Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)
#
#   Raumbezug Kennziffer                        Name  Zeitbezug        Wert
# 0      Bund        111  Bundesrepublik Deutschland       1995  81404089.0
# 1      Bund        111  Bundesrepublik Deutschland       1996  81529861.0
# 2      Bund        111  Bundesrepublik Deutschland       1997  81506158.0
# 3      Bund        111  Bundesrepublik Deutschland       1998  81416898.0
# 4      Bund        111  Bundesrepublik Deutschland       1999  81474463.0

# %%
print(filtered_inkar['Bereich'].unique())
indicators_csv = filtered_inkar['Bereich'].unique()
wanted_columns = ["Kennziffer", "Wert", "Zeitbezug"]
for bereich in indicators_csv:
    currentData = filtered_inkar[filtered_inkar['Bereich'] == bereich]
    currentData = currentData[wanted_columns]
    fileName = f"C:/Users/juliu/VSCODE/VSCODE/inkar-indicators/src/out/indicator_{bereich}.csv"
    currentData.to_csv(fileName, index=False)
# Out:
# ['Absolutzahlen' 'Beschäftigung und Erwerbstätigkeit' 'Bevölkerung'
#  'Öffentliche Finanzen' 'Wirtschaft' 'Zentrale Orte Monitoring']

# %%
# Out:
# array(['Bund', 'Bundesländer', 'Gemeindeverbände', 'Kreise', 'Gemeinden'],
#       dtype=object)
